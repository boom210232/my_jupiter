# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Euro 2012 (10 points)

# %% [markdown]
# Import Euro 2012 team stats dataset from `Euro_2012.csv`
#
# Note: please upload `Euro_2012.csv` file using File Explorer tool on your left
#
# ![image.png](data:image/png;base64,...)

# %%
euro2012 = pd.read_csv('Euro_2012.csv')
euro2012
# Out:
#                    Team  Goals  ...  Subs off  Players Used
# 0               Croatia      4  ...         9            16
# 1        Czech Republic      4  ...        11            19
# 2               Denmark      4  ...         7            15
# 3               England      5  ...        11            16
# 4                France      3  ...        11            19
# 5               Germany     10  ...        15            17
# 6                Greece      5  ...        12            20
# 7                 Italy      6  ...        18            19
# 8           Netherlands      2  ...         7            15
# 9                Poland      2  ...         7            17
# 10             Portugal      6  ...        14            16
# 11  Republic of Ireland      1  ...        10            17
# 12               Russia      5  ...         7            16
# 13                Spain     12  ...        17            18
# 14               Sweden      5  ...         9            18
# 15              Ukraine      2  ...         9            18
#
# [16 rows x 35 columns]

# %% [markdown]
# Get the number of teams participated in the Euro2012?

# %%
index = euro2012.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 16

# %% [markdown]
# List all the columns in the dataset using `info()`

# %%
euro2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
#  13  Passing Accuracy            16 non-null     object
#  14  Touches                     16 non-null     int64
#  15  Crosses                     16 non-null     int64
#  16  Dribbles                    16 non-null     int64
#  17  Corners Taken               16 non-null     int64
#  18  Tackles                     16 non-null     int64
#  19  Clearances                  16 non-null     int64
#  20  Interceptions               16 non-null     int64
#  21  Clearances off line         15 non-null     float64
#  22  Clean Sheets                16 non-null     int64
#  23  Blocks                      16 non-null     int64
#  24  Goals conceded              16 non-null     int64
#  25  Saves made                  16 non-null     int64
#  26  Saves-to-shots ratio        16 non-null     object
#  27  Fouls Won                   16 non-null     int64
#  28  Fouls Conceded              16 non-null     int64
#  29  Offsides                    16 non-null     int64
#  30  Yellow Cards                16 non-null     int64
#  31  Red Cards                   16 non-null     int64
#  32  Subs on                     16 non-null     int64
#  33  Subs off                    16 non-null     int64
#  34  Players Used                16 non-null     int64
# dtypes: float64(1), int64(29), object(5)
# memory usage: 4.5+ KB

# %% [markdown]
# Create a DataFrame `discipline` consisting of Team, Yellow Cards, Red Cards columns

# %%
discipline  = euro2012[["Team","Yellow Cards","Red Cards"]]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Sort the teams by Red Cards, then Yellow Cards in descending order

# %%
discipline.sort_values(["Red Cards","Yellow Cards"], ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# Compute the average number of Yellow Cards given per Team

# %%
euro2012["Yellow Cards"].mean()
# Out:
# 7.4375

# %% [markdown]
# Show a DataFrame of teams that scored more than 6 goals

# %%
more_six = euro2012[6 < euro2012["Goals"] ]
more_six
# Out:
#        Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 5   Germany     10               32  ...       15       15           17
# 13    Spain     12               42  ...       17       17           18
#
# [2 rows x 35 columns]

# %% [markdown]
# Show a DataFrame of teams that start with letter C
#
# Hint: `str.startswith()`

# %%
# euro2012_renamed = euro2012.copy()
# # Your code here
# for survived in range(len(euro2012_renamed)):
#   if euro2012_renamed['Team'].str.startswith("C")[survived] == True:
#     print(euro2012_renamed['Team'][survived])
euro2012[euro2012["Team"].str.startswith("C")]
# Out:
#              Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 0         Croatia      4               13  ...        9        9           16
# 1  Czech Republic      4               13  ...       11       11           19
#
# [2 rows x 35 columns]

# %% [markdown]
# Show the first 6 columns of the original DataFrame
#
# Hint: `.iloc()`

# %%
euro2012.iloc[0:,0:6]
# Out:
#                    Team  Goals  ...  Shooting Accuracy  % Goals-to-shots
# 0               Croatia      4  ...              51.9%             16.0%
# 1        Czech Republic      4  ...              41.9%             12.9%
# 2               Denmark      4  ...              50.0%             20.0%
# 3               England      5  ...              50.0%             17.2%
# 4                France      3  ...              37.9%              6.5%
# 5               Germany     10  ...              47.8%             15.6%
# 6                Greece      5  ...              30.7%             19.2%
# 7                 Italy      6  ...              43.0%              7.5%
# 8           Netherlands      2  ...              25.0%              4.1%
# 9                Poland      2  ...              39.4%              5.2%
# 10             Portugal      6  ...              34.3%              9.3%
# 11  Republic of Ireland      1  ...              36.8%              5.2%
# 12               Russia      5  ...              22.5%             12.5%
# 13                Spain     12  ...              55.9%             16.0%
# 14               Sweden      5  ...              47.2%             13.8%
# 15              Ukraine      2  ...              21.2%              6.0%
#
# [16 rows x 6 columns]

# %% [markdown]
# Show a DataFrame containing Shooting Accuracy from Greece, Germany and Sweden
#
# Hint: slice the original DataFrame by labels using `.loc()`

# %%
show_shoot = euro2012.loc[euro2012["Team"].isin(["Greece","Germany","Sweden"]) , ["Team", "Shooting Accuracy"]]
show_shoot
# Out:
#        Team Shooting Accuracy
# 5   Germany             47.8%
# 6    Greece             30.7%
# 14   Sweden             47.2%

# %% [markdown]
# # Alcohol Consumption (5 points)

# %% [markdown]
# Import dataset from `alcohol.csv`

# %%
alcohol = pd.read_csv('alcohol.csv')
alcohol
# Out:
#          country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0    Afghanistan              0  ...                           0.0         AS
# 1        Albania             89  ...                           4.9         EU
# 2        Algeria             25  ...                           0.7         AF
# 3        Andorra            245  ...                          12.4         EU
# 4         Angola            217  ...                           5.9         AF
# ..           ...            ...  ...                           ...        ...
# 188    Venezuela            333  ...                           7.7         SA
# 189      Vietnam            111  ...                           2.0         AS
# 190        Yemen              6  ...                           0.1         AS
# 191       Zambia             32  ...                           2.5         AF
# 192     Zimbabwe             64  ...                           4.7         AF
#
# [193 rows x 6 columns]

# %% [markdown]
# Which continent drinks more beer on average? List average beer consumption per continent.

# %%
more_avg = alcohol.groupby("continent").beer_servings.agg(["mean"])
more_avg
# Out:
#                  mean
# continent
# AF          61.471698
# AS          37.045455
# EU         193.777778
# OC          89.687500
# SA         175.083333

# %% [markdown]
# For each continent, `describe()` the statistics for wine consumption.

# %%
desc_wine = alcohol.groupby("continent").wine_servings.describe()
desc_wine
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# Show the mean alcohol consumption per continent for every alcohol type using the DataFrame layout below.
#
# ![image.png](data:image/png;base64,...)

# %%
alcohol.groupby("continent").mean()
# Out:
#            beer_servings  ...  total_litres_of_pure_alcohol
# continent                 ...
# AF             61.471698  ...                      3.007547
# AS             37.045455  ...                      2.170455
# EU            193.777778  ...                      8.617778
# OC             89.687500  ...                      3.381250
# SA            175.083333  ...                      6.308333
#
# [5 rows x 4 columns]

# %% [markdown]
# Show the mean, min and max values for spirit consumption using the DataFrame layout below.
#
# ![image.png](data:image/png;base64,...)

# %%
alcohol.groupby("continent").spirit_servings.agg(["mean","min","max"])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302

# %% [markdown]
# # Titanic (5 points)

# %% [markdown]
# Import titanic passenger data
#
# Note: please upload `titanic2.csv` file using File Explorer tool on your left
#
# **This is different from `titanic.csv` from the previous lab.**
#
# ![image.png](data:image/png;base64,...)

# %%
titanic = pd.read_csv('titanic2.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# Set `PassengerId` as the index
#
# Hint: use `set_index()` method

# %%
titanic.set_index("PassengerId")
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
# ...               ...     ...  ...   ...      ...
# 887                 0       2  ...   NaN        S
# 888                 1       1  ...   B42        S
# 889                 0       3  ...   NaN        S
# 890                 1       1  ...  C148        C
# 891                 0       3  ...   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# Visualize a pie chart representing the gender proportion
#
# example: ![image.png](data:image/png;base64,...)

# %%
label = ["Males","Females"]
color = ["Blue","Red"]
s=titanic.Sex.value_counts()
f1, a1=plt.subplots()
plt.title('Sex Proportion').set_fontsize(13)
a1.pie(s, labels=label, colors=color, autopct='%2.1f%%')
plt.show()

# %% [markdown]
# Visualize a scatter plot with the Fare and the Age, each dot colored by gender
#
# example: ![image.png](data:image/png;base64,...)

# %%
female = titanic[titanic.Sex == "female"].plot.scatter("Age","Fare",color="green",label="female")
male = titanic[titanic.Sex == "male"].plot.scatter("Age","Fare",color="blue",label="male",ax = female)

# %% [markdown]
# Visualize a histogram with the Fare
#
# example: ![image.png](data:image/png;base64,...)

# %%
plt.title("Fare Payed Histrogram")
plt.hist(titanic["Fare"], bins = np.arange(0,600,10))
plt.grid(True)
plt.ylabel("Frequency")
plt.xlabel("Fare")
plt.xlim([0,600])
# Out:
# (0.0, 600.0)

# %% [markdown]
# Visualize a bar plot representing survival rates in percent grouped by the passenger class

# %%
survive = titanic.groupby('Pclass').mean()['Survived']*100
survive.plot.bar(ylabel="Percentage of survival" , xlabel="Passenger Class" , color = ["Red", "Green" , "Blue"])

# %% [markdown]
# # Apple Stock (10 points)

# %% [markdown]
# Import dataset from `apple_stock_1980_2014.csv`

# %%
stock = pd.read_csv('apple_stock_1980_2014.csv')
stock
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# Print the type of each data column

# %%
stock.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# Convert the Date column to a datetime type

# %%
stock["Date"] = pd.to_datetime(stock["Date"])
stock
# Out:
#            Date   Open   High    Low  Close     Volume  Adj Close
# 0    2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1    2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2    2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3    2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4    2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...         ...    ...    ...    ...    ...        ...        ...
# 8460 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# Set the date as the index

# %%
stock = stock.set_index("Date")

# %% [markdown]
# Check if there is any duplicate dates

# %%
stock["Date"].is_unique
# Out:
# True

# %% [markdown]
# Currently, the index is from the most recent date. Sort the entries so that the oldest date comes first.

# %%
stock.sort_index(ascending = False)
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %% [markdown]
# Find the last business day of each month using `resample('BM')`

# %%
stock.resample('BM').mean()
# Out:
#                   Open        High  ...        Volume  Adj Close
# Date                                ...
# 1980-12-31   30.481538   30.567692  ...  2.586252e+07   0.473077
# 1981-01-30   31.754762   31.826667  ...  7.249867e+06   0.493810
# 1981-02-27   26.480000   26.572105  ...  4.231832e+06   0.411053
# 1981-03-31   24.937727   25.016818  ...  7.962691e+06   0.387727
# 1981-04-30   27.286667   27.368095  ...  6.392000e+06   0.423333
# ...                ...         ...  ...           ...        ...
# 2014-03-31  533.593333  536.453810  ...  5.954403e+07  75.750000
# 2014-04-30  540.081905  544.349048  ...  7.660787e+07  76.867143
# 2014-05-30  601.301905  606.372857  ...  6.828177e+07  86.058571
# 2014-06-30  222.360000  224.084286  ...  5.745506e+07  91.885714
# 2014-07-31   94.294000   95.004000  ...  4.218366e+07  94.470000
#
# [404 rows x 6 columns]

# %% [markdown]
# Compute the difference in days between the first and the last day

# %%
stock.index.max() - stock.index.min()
# Out:
# Timedelta('12261 days 00:00:00')

# %% [markdown]
# Compute the number of months in the data we have

# %%
stock.resample('BM').mean().shape[0]
# Out:
# 404

# %% [markdown]
# Plot the 'Adj Close' value.

# %%
adj_close = stock["Adj Close"].plot(title = "Adj close value" , color = "green")
